# %% [markdown]
# # Full Dataset Exploration

# %%
import json
import pandas as pd

# %%
df = pd.read_json("../../outputs/datasets/icu_entities_full.jsonl", lines=True)

# %%
len(df)
# Out:
# 780941

# %%
len(df["subject_id"].unique())
# Out:
# 8621

# %%
len(df["note_id"].unique())
# Out:
# 1000

# %%
df = pd.read_csv("../../data/processed/icu_corpus.csv")
print(len(df))

len(df["SUBJECT_ID"].unique())
# Out:
# 162296
# 25054

# %% [markdown]
# 1. Scale
#
# * Total number of notes processed (~160k)
# * Total number of entities extracted (~780k)
#
# 2. Distribution sanity checks
#
# These are high-value and low-effort:
#
# * Entities per note (mean, median)
# * Entity type distribution:
#     * SYMPTOM
#     * INTERVENTION
#     * CONDITION
# * Validation rate:
#     * % of entities where is_valid == True
